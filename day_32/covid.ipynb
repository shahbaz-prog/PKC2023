# %%
df = pd.read_csv("UK_Local_Authority_UTLA_COVID_Dataset.csv")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120141 entries, 0 to 120140
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   date                              120141 non-null  object
#  1   areaName                          120141 non-null  object
#  2   areaCode                          120141 non-null  object
#  3   newCasesByPublishDate             111457 non-null  float64
#  4   cumCasesByPublishDate             111718 non-null  float64
#  5   newDeaths28DaysByPublishDate      88296 non-null   float64
#  6   cumDeaths28DaysByPublishDate      93378 non-null   float64
#  7   cumDeaths28DaysByPublishDateRate  93378 non-null   float64
#  8   newDeaths28DaysByDeathDate        119961 non-null  float64
#  9   cumDeaths28DaysByDeathDate        119961 non-null  float64
#  10  cumDeaths28DaysByDeathDateRate    119961 non-null  float64
# dtypes: float64(8), object(3)
# ...

# %%
df.isnull().sum()/len(df)*100
# Out:
# date                                 0.000000
# areaName                             0.000000
# areaCode                             0.000000
# newCasesByPublishDate                7.228174
# cumCasesByPublishDate                7.010929
# newDeaths28DaysByPublishDate        26.506355
# cumDeaths28DaysByPublishDate        22.276325
# cumDeaths28DaysByPublishDateRate    22.276325
# newDeaths28DaysByDeathDate           0.149824
# cumDeaths28DaysByDeathDate           0.149824
# cumDeaths28DaysByDeathDateRate       0.149824
# dtype: float64

# %%
df = pd.read_csv("UK_National_Total_COVID_Dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 715 entries, 0 to 714
# Data columns (total 18 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        715 non-null    object
#  1   areaName                                    715 non-null    object
#  2   newCasesByPublishDate                       715 non-null    int64
#  3   cumCasesByPublishDate                       715 non-null    int64
#  4   newAdmissions                               659 non-null    float64
#  5   cumAdmissions                               659 non-null    float64
#  6   hospitalCases                               658 non-null    float64
#  7   covidOccupiedMVBeds                         652 non-null    float64
#  8   newTestsByPublishDate                       654 non-null    float64
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of            date        areaName  newCasesByPublishDate  cumCasesByPublishDate  \
# 0    2020-01-31  United Kingdom                      2                      2
# 1    2020-02-01  United Kingdom                      0                      2
# 2    2020-02-02  United Kingdom                      0                      2
# 3    2020-02-03  United Kingdom                      0                      2
# 4    2020-02-04  United Kingdom                      0                      2
# ..          ...             ...                    ...                    ...
# 710  2022-01-10  United Kingdom                 142224               14617314
# 711  2022-01-11  United Kingdom                 120821               14732594
# 712  2022-01-12  United Kingdom                 129587               14862138
# 713  2022-01-13  United Kingdom                 109133               14967817
# 714  2022-01-14  United Kingdom                  99652               15066395
#
# ...

# %%
df.columns
# Out:
# Index(['date', 'areaName', 'newCasesByPublishDate', 'cumCasesByPublishDate',
#        'newAdmissions', 'cumAdmissions', 'hospitalCases',
#        'covidOccupiedMVBeds', 'newTestsByPublishDate', 'cumTestsByPublishDate',
#        'newDeaths28DaysByPublishDate', 'cumDeaths28DaysByPublishDate',
#        'cumDeaths28DaysByPublishDateRate', 'newDeaths28DaysByDeathDate',
#        'cumDeaths28DaysByDeathDate', 'cumDeaths28DaysByDeathDateRate',
#        'cumPeopleVaccinatedFirstDoseByPublishDate',
#        'cumPeopleVaccinatedSecondDoseByPublishDate'],
#       dtype='object')

# %%
df.isnull().sum()/len(df)*100
# Out:
# date                                           0.000000
# areaName                                       0.000000
# newCasesByPublishDate                          0.000000
# cumCasesByPublishDate                          0.000000
# newAdmissions                                  7.832168
# cumAdmissions                                  7.832168
# hospitalCases                                  7.972028
# covidOccupiedMVBeds                            8.811189
# newTestsByPublishDate                          8.531469
# cumTestsByPublishDate                          8.531469
# newDeaths28DaysByPublishDate                   4.895105
# cumDeaths28DaysByPublishDate                   4.895105
# cumDeaths28DaysByPublishDateRate               6.153846
# newDeaths28DaysByDeathDate                     4.475524
# cumDeaths28DaysByDeathDate                     4.475524
# cumDeaths28DaysByDeathDateRate                 5.874126
# cumPeopleVaccinatedFirstDoseByPublishDate     48.251748
# ...

# %%
df["newAdmissions"] = df.newAdmissions.fillna(value = df["newAdmissions"].mean())
df["hospitalCases"] = df.hospitalCases.fillna(value = df["hospitalCases"].mean())
df["covidOccupiedMVBeds"] = df.covidOccupiedMVBeds.fillna(value = df["covidOccupiedMVBeds"].mean())
df["newTestsByPublishDate"] = df.newTestsByPublishDate.fillna(value = df["newTestsByPublishDate"].mean())
df["cumDeaths28DaysByPublishDate"] = df.cumDeaths28DaysByPublishDate.fillna(value = df["cumDeaths28DaysByPublishDate"].mean())
df["newDeaths28DaysByPublishDate"] = df.newDeaths28DaysByPublishDate.fillna(value = df["newDeaths28DaysByPublishDate"].mean())
df["cumAdmissions"] = df.cumAdmissions.fillna(value = df["cumAdmissions"].mean())
df["cumDeaths28DaysByPublishDate"] = df.cumDeaths28DaysByPublishDate.fillna(value = df["cumDeaths28DaysByPublishDate"].mean())
df["cumDeaths28DaysByPublishDateRate"] = df.cumDeaths28DaysByPublishDateRate.fillna(value = df["cumDeaths28DaysByPublishDateRate"].mean())
df["newDeaths28DaysByDeathDate"] = df.newDeaths28DaysByDeathDate.fillna(value = df["newDeaths28DaysByDeathDate"].mean())
df["cumTestsByPublishDate"] = df.cumTestsByPublishDate .fillna(value = df["cumTestsByPublishDate"].mean())
df["cumDeaths28DaysByDeathDate"] = df.cumDeaths28DaysByDeathDate.fillna(value = df["cumDeaths28DaysByDeathDate"].mean())
df["cumDeaths28DaysByDeathDateRate"] = df.cumDeaths28DaysByDeathDateRate.fillna(value = df["cumDeaths28DaysByDeathDateRate"].mean())

# %%
df.isnull().sum()/len(df)*100
# Out:
# date                                           0.000000
# areaName                                       0.000000
# newCasesByPublishDate                          0.000000
# cumCasesByPublishDate                          0.000000
# newAdmissions                                  0.000000
# cumAdmissions                                  0.000000
# hospitalCases                                  0.000000
# covidOccupiedMVBeds                            0.000000
# newTestsByPublishDate                          0.000000
# cumTestsByPublishDate                          0.000000
# newDeaths28DaysByPublishDate                   0.000000
# cumDeaths28DaysByPublishDate                   0.000000
# cumDeaths28DaysByPublishDateRate               0.000000
# newDeaths28DaysByDeathDate                     0.000000
# cumDeaths28DaysByDeathDate                     0.000000
# cumDeaths28DaysByDeathDateRate                 0.000000
# cumPeopleVaccinatedFirstDoseByPublishDate     48.251748
# ...

# %%
df = df.drop(columns=["cumPeopleVaccinatedFirstDoseByPublishDate","cumPeopleVaccinatedSecondDoseByPublishDate"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 715 entries, 0 to 714
# Data columns (total 16 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   date                              715 non-null    object
#  1   areaName                          715 non-null    object
#  2   newCasesByPublishDate             715 non-null    int64
#  3   cumCasesByPublishDate             715 non-null    int64
#  4   newAdmissions                     715 non-null    float64
#  5   cumAdmissions                     715 non-null    float64
#  6   hospitalCases                     715 non-null    float64
#  7   covidOccupiedMVBeds               715 non-null    float64
#  8   newTestsByPublishDate             715 non-null    float64
#  9   cumTestsByPublishDate             715 non-null    float64
#  10  newDeaths28DaysByPublishDate      715 non-null    float64
# ...

# %%
df.describe()
# Out:
#        newCasesByPublishDate  cumCasesByPublishDate  newAdmissions  \
# count             715.000000           7.150000e+02     715.000000
# mean            21318.202797           3.647354e+06    1001.465857
# std             30198.929520           3.628410e+06     878.272467
# min                 0.000000           2.000000e+00      73.000000
# 25%              2290.500000           3.065775e+05     289.500000
# 50%              9055.000000           3.583907e+06     851.000000
# 75%             32549.500000           5.496540e+06    1258.000000
# max            218724.000000           1.506640e+07    4583.000000
#
#        cumAdmissions  hospitalCases  covidOccupiedMVBeds  \
# count     715.000000     715.000000           715.000000
# mean   344910.576631    9277.212766          1008.420245
# std    182926.005233    8298.765893           900.888244
# min      4882.000000     770.000000            60.000000
# 25%    139284.500000    2754.500000           329.500000
# ...

# %%
df.describe().T
# Out:
#                                   count          mean           std       min  \
# newCasesByPublishDate             715.0  2.131820e+04  3.019893e+04       0.0
# cumCasesByPublishDate             715.0  3.647354e+06  3.628410e+06       2.0
# newAdmissions                     715.0  1.001466e+03  8.782725e+02      73.0
# cumAdmissions                     715.0  3.449106e+05  1.829260e+05    4882.0
# hospitalCases                     715.0  9.277213e+03  8.298766e+03     770.0
# covidOccupiedMVBeds               715.0  1.008420e+03  9.008882e+02      60.0
# newTestsByPublishDate             715.0  6.204312e+05  4.229264e+05   11896.0
# cumTestsByPublishDate             715.0  1.377674e+08  1.248169e+08  155174.0
# newDeaths28DaysByPublishDate      715.0  2.227103e+02  3.039942e+02       0.0
# cumDeaths28DaysByPublishDate      715.0  8.867924e+04  4.671989e+04       1.0
# cumDeaths28DaysByPublishDateRate  715.0  1.339709e+02  6.802574e+01       0.1
# ...

# %%
df.columns
# Out:
# Index(['date', 'areaName', 'newCasesByPublishDate', 'cumCasesByPublishDate',
#        'newAdmissions', 'cumAdmissions', 'hospitalCases',
#        'covidOccupiedMVBeds', 'newTestsByPublishDate', 'cumTestsByPublishDate',
#        'newDeaths28DaysByPublishDate', 'cumDeaths28DaysByPublishDate',
#        'cumDeaths28DaysByPublishDateRate', 'newDeaths28DaysByDeathDate',
#        'cumDeaths28DaysByDeathDate', 'cumDeaths28DaysByDeathDateRate'],
#       dtype='object')

# %%
df.head()
# Out:
#          date        areaName  newCasesByPublishDate  cumCasesByPublishDate  \
# 0  2020-01-31  United Kingdom                      2                      2
# 1  2020-02-01  United Kingdom                      0                      2
# 2  2020-02-02  United Kingdom                      0                      2
# 3  2020-02-03  United Kingdom                      0                      2
# 4  2020-02-04  United Kingdom                      0                      2
#
#    newAdmissions  cumAdmissions  hospitalCases  covidOccupiedMVBeds  \
# 0    1001.465857  344910.576631    9277.212766          1008.420245
# 1    1001.465857  344910.576631    9277.212766          1008.420245
# 2    1001.465857  344910.576631    9277.212766          1008.420245
# 3    1001.465857  344910.576631    9277.212766          1008.420245
# 4    1001.465857  344910.576631    9277.212766          1008.420245
#
#    newTestsByPublishDate  cumTestsByPublishDate  newDeaths28DaysByPublishDate  \
# ...

# %%
df["areaName"].unique()
# Out:
# array(['United Kingdom'], dtype=object)

# %%
df = df.rename(columns={"areaName":"country", "newCasesByPublishDate":"new_cases", })
