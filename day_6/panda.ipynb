# %% [markdown]
# ## how to import data in python using pandas library
# Written by : Qadir Shahbaz\
# Date: 08.01.2023\
# Email: qadir_shahbaz@yahoo.co.uk

# %%
# step 1:
# Import libraries
import pandas as pd

# %%
# Step 2
# Import dataset
df = pd.read_excel("pandas_01_day6.xlsx")

# %%
print(df)
# Out:
#    Height Weight Favourite Dish
# 0     5.8    101  Chicken Pulao
# 1     6.2     92        Biryani
# 2     5.9     62  Karahi Ghosht
# 3     5.9     95  Chicken Pulao
# 4     5.9     55  Chicken Pulao
# ..    ...    ...            ...
# 82    5.4     55          Pasta
# 83    5.9   75KG  Karahi Ghosht
# 84    5.4     61        Biryani
# 85    6.2     68  Chicken Pulao
# 86    5.1     96        Biryani
#
# [87 rows x 3 columns]

# %%
df.head()
# Out:
#   Height Weight Favourite Dish
# 0    5.8    101  Chicken Pulao
# 1    6.2     92        Biryani
# 2    5.9     62  Karahi Ghosht
# 3    5.9     95  Chicken Pulao
# 4    5.9     55  Chicken Pulao

# %%
# if you want to see the first 10 rows of the data set
df.head(10)
# Out:
#   Height Weight Favourite Dish
# 0    5.8    101  Chicken Pulao
# 1    6.2     92        Biryani
# 2    5.9     62  Karahi Ghosht
# 3    5.9     95  Chicken Pulao
# 4    5.9     55  Chicken Pulao
# 5    5.3     59        Biryani
# 6    5.6     50          Pasta
# 7    5.9     76        Biryani
# 8    5.1     78        Biryani
# 9    5.4     68        Biryani

# %%
df.tail()
# Out:
#    Height Weight Favourite Dish
# 82    5.4     55          Pasta
# 83    5.9   75KG  Karahi Ghosht
# 84    5.4     61        Biryani
# 85    6.2     68  Chicken Pulao
# 86    5.1     96        Biryani

# %%
df.shape
# Out:
# (87, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Height          87 non-null     object
#  1   Weight          87 non-null     object
#  2   Favourite Dish  87 non-null     object
# dtypes: object(3)
# memory usage: 2.2+ KB

# %%
df.index
# Out:
# RangeIndex(start=0, stop=87, step=1)

# %%
df.columns
# Out:
# Index(['Height', 'Weight', 'Favourite Dish'], dtype='object')

# %%
df.describe()
# Out:
#         Height  Weight Favourite Dish
# count     87.0      87             87
# unique    35.0      47              5
# top        5.9      55        Biryani
# freq       9.0       6             40

# %%
df.T
#transpose row and colomn
# Out:
#                            0        1              2              3   \
# Height                    5.8      6.2            5.9            5.9
# Weight                    101       92             62             95
# Favourite Dish  Chicken Pulao  Biryani  Karahi Ghosht  Chicken Pulao
#
#                            4        5      6        7        8        9   ...  \
# Height                    5.9      5.3    5.6      5.9      5.1      5.4  ...
# Weight                     55       59     50       76       78       68  ...
# Favourite Dish  Chicken Pulao  Biryani  Pasta  Biryani  Biryani  Biryani  ...
#
#                      77             78       79     80             81     82  \
# Height              5.5           5’11      5'3    5.4            5.5    5.4
# Weight               85             72       62     55             52     55
# Favourite Dish  Biryani  Karahi Ghosht  Biryani  Pasta  Karahi Ghosht  Pasta
#
#                            83       84             85       86
# ...

# %%
df.sort_index()
# Out:
#    Height Weight Favourite Dish
# 0     5.8    101  Chicken Pulao
# 1     6.2     92        Biryani
# 2     5.9     62  Karahi Ghosht
# 3     5.9     95  Chicken Pulao
# 4     5.9     55  Chicken Pulao
# ..    ...    ...            ...
# 82    5.4     55          Pasta
# 83    5.9   75KG  Karahi Ghosht
# 84    5.4     61        Biryani
# 85    6.2     68  Chicken Pulao
# 86    5.1     96        Biryani
#
# [87 rows x 3 columns]

# %%
df.sort_index(ascending=False)
# Out:
#    Height Weight Favourite Dish
# 86    5.1     96        Biryani
# 85    6.2     68  Chicken Pulao
# 84    5.4     61        Biryani
# 83    5.9   75KG  Karahi Ghosht
# 82    5.4     55          Pasta
# ..    ...    ...            ...
# 4     5.9     55  Chicken Pulao
# 3     5.9     95  Chicken Pulao
# 2     5.9     62  Karahi Ghosht
# 1     6.2     92        Biryani
# 0     5.8    101  Chicken Pulao
#
# [87 rows x 3 columns]

# %%
df.head()
df
# Out:
#    Height Weight Favourite Dish
# 0     5.8    101  Chicken Pulao
# 1     6.2     92        Biryani
# 2     5.9     62  Karahi Ghosht
# 3     5.9     95  Chicken Pulao
# 4     5.9     55  Chicken Pulao
# ..    ...    ...            ...
# 82    5.4     55          Pasta
# 83    5.9   75KG  Karahi Ghosht
# 84    5.4     61        Biryani
# 85    6.2     68  Chicken Pulao
# 86    5.1     96        Biryani
#
# [87 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Height          87 non-null     object
#  1   Weight          87 non-null     object
#  2   Favourite Dish  87 non-null     object
# dtypes: object(3)
# memory usage: 2.2+ KB
